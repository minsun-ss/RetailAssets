# %% [markdown]
# ## Notes to self
#
# Money amounts are reported in thousands
#
# AGI_STUB: Size of adjusted gross income - must aggregate together for entirety of zip code
#
# N00300: # of returns with taxable interest (Taxable bonds?)
#
# A00300: dollar amount Taxable interest amounts
#
# N00600: # of returns with ordinary dividends (Equities?)
#
# A00600: dollar amount ordinary dividend amounts
#
# N00650: # of returns with qualified dividends (Equities?)
#
# A00650: dollar amount qualified dividend amounts
#
# ## Data from Federal Flow of Funds
# 2016 data - L.101
# Total financial assets: 78314.1 billion
#
# Debt securities: 4512.1 billion
#
# Equities: 14806.6 billion
#
# Problems with this data: household data is commingled with hedge fund data
#
# 2016 data - B.101h - Balance Sheet of Households
#
# Total assets: 103737.2 billion
# Total financial assets: 75572.7 billion
#
# Debt securities: 4315.8 billion
#
# Equities and mutual fund shares: 20525.5
#
# Problems with this data: mutual fund data is commingled with equity data. Surprisingly, it seems that the majority of the L.101 direct holdings table is actually from households and not hedge funds? 4.3 trillion bonds out of 4.5 trillion? This strikes me as odd when you consider the SCF data. I wonder how the St Louis fed reconciled this data.
#
#
# ## Data from SCF and Census
# 2016
#
# 1.2% of all households hold bonds (mean value 771.0k)
# 13.9% of all households hold stocks (mean value 327.8k)
# Number of households, census, 2016: 125.82 million
#
# Value of all bonds: 1.2% * 125,820,000 * 771,000 = 1164.086640 billion
# Value of all stocks: 13.9% * 125,820,000 * 327,800 = 5732.887644 billion

# %%
import pandas as pd
import numpy as np
DATA_POINTS = ['N00300', 'A00300', 'N00600', 'A00600', 'N00650', 'A00650']
DATA_NAMES = ['NumTaxInt', 'DolTaxInt', 'NumOrdDiv', 
             'DolOrdDiv', 'NumQualDiv', 
              'DolQualDiv']

df = pd.read_csv('data/16zpallagi.csv')
amounts = df.groupby(['STATE', 'zipcode'])[DATA_POINTS].sum()
amounts.columns = DATA_NAMES
amounts['TaxInterestPP'] = amounts['DolTaxInt']/amounts['NumTaxInt']

sumTaxInterest = amounts['DolTaxInt'].sum()

amounts
# Out:
#                NumTaxInt  DolTaxInt  NumOrdDiv  DolOrdDiv  NumQualDiv  \
# STATE zipcode
# AK    0            85500     126615      81210     357254       71050
#       99501         2100       4765       1980      16882        1730
#       99502         3230       7164       2860      18063        2560
#       99503         1540       3618       1530      14573        1310
#       99504         3920       3407       3480      11070        2940
#       99505          210         27        140        168         130
#       99506          310         59        200        171         170
#       99507         4780       6565       4370      21325        3890
#       99508         3020       4733       3080      20625        2620
#       99510          120        216        100        741          90
#       99515         3270       5520       2880      18338        2590
#       99516         4450       7854       3680      25729        3390
#       99517         2230       5001       2190      14419        1930
#       99518         1250       1840       1110       3089         950
#       99519          180        216        110        578         110
#       99540           70         19         40        113          40
#       99551            0          0          0          0           0
#       99552            0          0          0          0           0
#       99553            0          0          0          0           0
#       99554            0          0          0          0           0
#       99556          300        511        190        584         160
#       99557            0          0        180        129         160
#       99559          350        193        470        869         370
#       99561            0          0         40         36           0
#       99563            0          0          0          0           0
#       99567         1350       1051       1020       2591         900
#       99568           40         22         30         18          20
#       99572           80         37         50        209          40
#       99573          110         40        120        212         110
#       99574          380        533        420       2300         350
# ...                  ...        ...        ...        ...         ...
# WY    82937          370        314        180        411         160
#       82939          240        236        140        322         120
#       82941          700       1296        490       4151         460
#       82943           40         12          0          0           0
#       82944           40          8          0          0           0
#       82945            0          0          0          0           0
#       83001         2340      48961       2040     158991        1960
#       83002         1420      14023       1210      38640        1150
#       83011           40       1147         40       5110          40
#       83012          100         68         80       1983          70
#       83013           70        307         60        819          50
#       83014          880      23947        870     111402         840
#       83025          200       8333        220      26574         220
#       83101          410        406        260        831         250
#       83110          590       1657        300       1461         270
#       83111           50         25         20         11          20
#       83112           90         65         50        350          50
#       83113          250        248        220        456         180
#       83114          110         45         30         58          30
#       83115           70         90         60        259          60
#       83116           70         34         20         26          20
#       83118          110         38         60        112          60
#       83120           60        164         20        415           0
#       83122           30         15          0          0           0
#       83123           50         24         40         44          40
#       83126           50         64         20         16           0
#       83127          590       1066        350       2564         310
#       83128          290       1108        190       2158         190
#       83414          110        553        100       1558          90
#       99999         2740       8672       1620      19961        1500
#
#                DolQualDiv  TaxInterestPP
# STATE zipcode
# AK    0            278189       1.480877
#       99501         13241       2.269048
#       99502         14094       2.217957
#       99503         11126       2.349351
#       99504          8440       0.869133
#       99505           121       0.128571
#       99506           105       0.190323
#       99507         16868       1.373431
#       99508         16958       1.567219
#       99510           594       1.800000
#       99515         14615       1.688073
#       99516         20481       1.764944
#       99517         10767       2.242601
#       99518          2370       1.472000
#       99519           453       1.200000
#       99540            83       0.271429
#       99551             0            NaN
#       99552             0            NaN
#       99553             0            NaN
#       99554             0            NaN
#       99556           462       1.703333
#       99557            87            NaN
#       99559           644       0.551429
#       99561             0            NaN
#       99563             0            NaN
#       99567          1963       0.778519
#       99568             8       0.550000
#       99572           153       0.462500
#       99573           165       0.363636
#       99574          1877       1.402632
# ...                   ...            ...
# WY    82937           267       0.848649
#       82939           170       0.983333
#       82941          3404       1.851429
#       82943             0       0.300000
#       82944             0       0.200000
#       82945             0            NaN
#       83001        100708      20.923504
#       83002         30788       9.875352
#       83011          1955      28.675000
#       83012           739       0.680000
#       83013           516       4.385714
#       83014         96563      27.212500
#       83025         22148      41.665000
#       83101           533       0.990244
#       83110          1162       2.808475
#       83111             9       0.500000
#       83112           284       0.722222
#       83113           373       0.992000
#       83114            22       0.409091
#       83115           174       1.285714
#       83116            17       0.485714
#       83118            83       0.345455
#       83120             0       2.733333
#       83122             0       0.500000
#       83123            43       0.480000
#       83126             0       1.280000
#       83127          1930       1.806780
#       83128          1770       3.820690
#       83414          1053       5.027273
#       99999         14935       3.164964
#
# [29974 rows x 7 columns]
